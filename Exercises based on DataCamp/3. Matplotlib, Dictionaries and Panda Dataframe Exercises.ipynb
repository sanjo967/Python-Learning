# %% [markdown]
# ### Section 1 **Matplotlib Customization Challenge**
#
# #### **Objective:**
# Create a **customized line plot** that visualizes the **world population growth** over time using Matplotlib.
#
# #### **Steps to Follow:**
# 1. **Import Matplotlib.**
# 2. **Create two lists**:
#    - `years`: **[1800, 1850, 1900, 1950, 2000, 2050, 2100]**
#    - `population`: **[1.0, 1.2, 1.6, 2.5, 6.1, 9.7, 10.5]** (Population in billions)
# 3. **Plot the data as a line chart.**
# 4. **Customize your chart:**
#    - Add **x-axis and y-axis labels**.
#    - Add a **title** to describe the chart.
#    - Adjust **y-axis ticks** to show values in **billions (e.g., 2B, 4B, etc.)**.
# 5. **Display the plot.**
#
# ---
#
# ### **Bonus Challenge**
# 💡 Try adding a **scatter plot** on top of the line plot to highlight the data points.
#
# ---
#
# **Your turn!** Try coding this in Python, and let me know when you're ready for feedback! 🚀

# %%
#1. Importing matplotlib as plt
import matplotlib.pyplot as plt

#2. Creating lists
years = [1800, 1850, 1900, 1950, 2000, 2050, 2100]
population = [1.0, 1.2, 1.6, 2.5, 6.1, 9.7, 10.5]

#3. Plotting the data as a line chart
plt.plot(years, population, label= "poluation growth")

#4. Customising the chart

plt.xlabel("Years")
plt.ylabel("Population")
plt.title("World Population growth")
plt.yticks([2, 4, 6, 8, 10, 12],
           ["2B", "4B", "6B", "8B", "10B", "12B"])


#Bonus Challenging: Adding scatter plot
plt.scatter(years, population, color="red", label= "data points")

plt.legend()
plt.show()

# %% [markdown]
# ### **📌 Mastering Dictionaries & Pandas: Exercise Set**
#
# These exercises will test your understanding of **dictionaries and Pandas**, ensuring you master the core concepts. Try solving them on your own before checking your answers! 🚀
#
# ---
#
# ## **🔥 Section 2: Working with Python Dictionaries**
# ### **1. Creating a Dictionary**
# - Create a dictionary called `world_population` that contains the following key-value pairs:
#   - `"USA"` → `331`
#   - `"India"` → `1391`
#   - `"China"` → `1444`
#   - `"Brazil"` → `213`
#   - `"South Africa"` → `60`

# %%
#Creating world_population

world_population={"USA":331, "India":1391, "China":1444, "Brazil":213, "South Africa":60}
world_population
# Out:
# {'USA': 331, 'India': 1391, 'China': 1444, 'Brazil': 213, 'South Africa': 60}

# %% [markdown]
# ### **2.Accessing Dictionary Values**
# Print the population of India from world_population.

# %%
#Printing population of india
print("The population of India is",world_population["India"])
# Out:
# The population of India is 1391

# %% [markdown]
# ### **3. Adding & Updating**
# Add "Nigeria" with a population of 206 to the dictionary.
# Update "Brazil"’s population to 215.

# %%
#Adding Nigeria to the dictionary
world_population["Nigeria"]=206
print(world_population)

#Updating Brazils Population
world_population["Brazil"]=215
print(world_population)
# Out:
# {'USA': 331, 'India': 1391, 'China': 1444, 'Brazil': 213, 'South Africa': 60, 'Nigeria': 206}
# {'USA': 331, 'India': 1391, 'China': 1444, 'Brazil': 215, 'South Africa': 60, 'Nigeria': 206}

# %% [markdown]
# ### **4. Checking for a Key**
# Write a condition that checks if "Germany" exists in world_population.
# Print "Exists" if found, otherwise print "Not found".

# %%
if "Germany" in world_population:
  print("Exists")
else:
  print("Not found")
# Out:
# Not found

# %% [markdown]
# ### **5. Removing Data**
# Delete "South Africa" from world_population.
# Print the updated dictionary.

# %%
#Removing South Arica from world_population
world_population['South Africa']=60

#Print world population
print(world_population)
# Out:
# {'USA': 331, 'India': 1391, 'China': 1444, 'Brazil': 215, 'Nigeria': 206, 'South Africa': 60}

# %%
#Let us remove South Africa
del(world_population["South Africa"])
print(world_population)
# Out:
# {'USA': 331, 'India': 1391, 'China': 1444, 'Brazil': 215, 'Nigeria': 206}

# %% [markdown]
# # **🔥 Section 2: Creating & Modifying a Pandas DataFrame**
# ### 6. Creating a DataFrame from a Dictionary
#
# Create a dictionary called brics_data containing:
# "Country" → ["Brazil", "Russia", "India", "China", "South Africa"]
#
# "Capital" → ["Brasília", "Moscow", "New Delhi", "Beijing", "Pretoria"]
#
# "Area" → [8.5, 17.1, 3.3, 9.6, 1.2] (in million km²)
#
# "Population" → [213, 144, 1391, 1444, 60] (in millions)
#
# Convert this dictionary into a Pandas DataFrame named brics.
#
# Set the index to ["BR", "RU", "IN", "CH", "ZA"].

# %%
# Creating Brics Dictionary
brics_data = {"Country": ["Brazil", "Russia", "India", "China", "South Africa"],
              "Capital": ["Brasília", "Moscow", "New Delhi", "Beijing", "Pretoria"],
              "Area": [8.5, 17.1, 3.3, 9.6, 1.2],
              "Population": [213, 144, 1391, 1444, 60],} #Setting up columns

#Converting dictionary to dataframe
import pandas as pd
brics=pd.DataFrame(brics_data)


#Setting index as ["BR", "RU", "IN", "CH", "ZA"].
brics.index=["BR", "RU", "IN", "CH", "ZA"]

#Printing brics to check
print(brics)
# Out:
#          Country    Capital  Area  Population
# BR        Brazil   Brasília   8.5         213
# RU        Russia     Moscow  17.1         144
# IN         India  New Delhi   3.3        1391
# CH         China    Beijing   9.6        1444
# ZA  South Africa   Pretoria   1.2          60

# %% [markdown]
# ### **7. Selecting Columns**
# Extract the "Country" column and print it as a Series.
#
# Extract the "Country" column and print it as a DataFrame.
#
# Select the "Country" and "Capital" columns and print them.

# %%
#Extracting "Country" column as series
print(brics["Country"])
#Printing type
print(type(brics["Country"]))
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# ZA    South Africa
# Name: Country, dtype: object
# <class 'pandas.core.series.Series'>

# %%
#Extracting "Country" as a dataframe
print(brics[["Country"]])
print(type(brics[["Country"]]))
# Out:
#          Country
# BR        Brazil
# RU        Russia
# IN         India
# CH         China
# ZA  South Africa
# <class 'pandas.core.frame.DataFrame'>

# %%
#Extracting "Country" and "Capital" Columns
print(brics["Country", "Capital"])
print(type(brics["Country"]))
# Out:
#          Country    Capital
# BR        Brazil   Brasília
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# ZA  South Africa   Pretoria

# %% [markdown]
# ### **8. Selecting Rows**
# Select the row for "India" using .loc[].
#
# Select the row for "India" using .iloc[].

# %%
#Select the row for "India" using .loc[]
brics.loc['IN']
# Out:
# Country           India
# Capital       New Delhi
# Area                3.3
# Population         1391
# Name: IN, dtype: object

# %%
#Select the row for "India" using .iloc[]
brics.iloc[2]
# Out:
# Country           India
# Capital       New Delhi
# Area                3.3
# Population         1391
# Name: IN, dtype: object

# %% [markdown]
# ### **9. Selecting Rows & Columns**
# Using .loc[], select Russia and China, but only return their "Capital" and "Population".
#
# Using .iloc[], select the same rows and columns by position.

# %%
#Selecting Russia and China Capital and Population but using .loc method
brics.loc[["RU","CH"], ["Capital", "Population"]]
# Out:
#     Capital  Population
# RU   Moscow         144
# CH  Beijing        1444

# %%
#Selecting Russia and China Capital and Population but using .iloc method
brics.iloc[[1,3], [1, 3]]
# Out:
#     Capital  Population
# RU   Moscow         144
# CH  Beijing        1444

# %% [markdown]
# ### **10. Importing Data from a CSV File**
# Load the dataset from a file named "brics.csv" into a Pandas DataFrame named brics_df.
#
# Ensure the first column is used as the index.
#
# Print the first 5 rows.

# %%
import pandas as pd

# Importing data from CSV (Setting the first column as index)
brics_df = pd.read_csv("brics.csv", index_col=0)

# Printing the first five rows
print(brics_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-c1cfe244c7b1> in <cell line: 0>()
#       2
#       3 # Importing data from CSV (Setting the first column as index)
# ----> 4 brics_df = pd.read_csv("brics.csv", index_col=0)
#       5
#       6 # Printing the first five rows
#
# ...

# %% [markdown]
# # **Bonus Challenges (Optional)**
#
# 💡 Challenge 1:
#
# Add a new country "Nigeria" to the brics DataFrame with:
# "Capital" → "Abuja"
# "Area" → 0.923
# "Population" → 206

# %%
#Adding nigeria row to brics dataframe
brics.loc["NI"]=["Nigeria", "Abuja", 0.923, 206]
brics
# Out:
#          Country    Capital    Area  Population
# BR        Brazil   Brasília   8.500         213
# RU        Russia     Moscow  17.100         144
# IN         India  New Delhi   3.300        1391
# CH         China    Beijing   9.600        1444
# ZA  South Africa   Pretoria   1.200          60
# NI       Nigeria      Abuja   0.923         206

# %% [markdown]
# Challenge 2:
#
# Remove "South Africa" from the brics DataFrame.

# %%
#Removing South African Row from brics datframe
brics=brics.drop("ZA")
brics
# Out:
#     Country    Capital    Area  Population
# BR   Brazil   Brasília   8.500         213
# RU   Russia     Moscow  17.100         144
# IN    India  New Delhi   3.300        1391
# CH    China    Beijing   9.600        1444
# NI  Nigeria      Abuja   0.923         206

# %% [markdown]
#  Challenge 3:
#
# Use .loc[] to update "India"'s population to 1400.

# %%
#Updating India's population to 1400 with the .loc[]
brics.loc[["IN"], ["Population"]]=1400
brics
# Out:
#     Country    Capital    Area  Population
# BR   Brazil   Brasília   8.500         213
# RU   Russia     Moscow  17.100         144
# IN    India  New Delhi   3.300        1400
# CH    China    Beijing   9.600        1444
# NI  Nigeria      Abuja   0.923         206
