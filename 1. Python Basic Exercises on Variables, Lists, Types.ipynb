# %% [markdown]
# # Exercise 1
# Create Variables
#
# ## Create four variables: my_name, my_age, my_height, and is_student.
# Use appropriate data types for each (string, integer, float, and boolean).
# Print the types using type() to confirm they’re correct.

# %%
#Creating variables
my_name = "Sanjo"
my_age = 28
my_height = 1.9 #in metres
is_student = True

# %% [markdown]
# # Exercise 2
# ## String and Integer
#
# Print a sentence that includes both your name and your age in one string (using string concatenation or f-strings, whichever you prefer).
# Make sure there are no type errors.

# %%
print(str(my_name) + " is " + str (my_age) +" years old")
# Out:
# Sanjo is 28 years old

# %% [markdown]
# # Exercise 3
# ## List Creation
#
# Create a list called my_list that holds:
# your name,
# your age,
# your height,
# your boolean is_student.

# %%
#Creating list
my_list=[my_name, my_age, my_height,is_student]
print(my_list)
# Out:
# ['Sanjo', 28, 1.9, True]

# %% [markdown]
# # Exercise 4
# ## Subsetting
#
# Print the first element of my_list.
# Print the last element of my_list using a negative index.

# %%
#Print first element of list
print(my_list[0])
print(my_list[-1])
# Out:
# Sanjo
# True

# %% [markdown]
# # Exercise 5
# ## Slicing
# Create a slice of my_list containing only your age and height. Print the result.
# List Manipulation

# %%
#Creating new list with my name
my_list_2=my_list[1:3]
print(my_list_2)
# Out:
# [28, 1.9]

# %% [markdown]
# # Exercise 6
# ## List Manipulation
#
# Change the height in my_list to be some updated value (e.g., if you grew or made a correction).
# Add a new element (e.g., your favorite color as a string) at the end of my_list using list addition (+) or an appropriate list method.
# Remove the is_student element from my_list using del.

# %%
#Defining my_list
my_list=[my_name, my_age, my_height,is_student]

#Change the height in my_list
my_list[2]=2.3

#Change the height in my_list
my_list.append("red")

#Remove is_student element, which is at index 3
del(my_list[3])
print(my_list)
# Out:
# ['Sanjo', 28, 2.3, 'red']

# %% [markdown]
# # Exercise 7
# ## Copying vs. Referencing
#
# Create a new variable my_list_copy that is a true copy of my_list (not just a reference).
# (Hint: use slicing or list().)
# Change something in my_list_copy.
# Print both my_list_copy and my_list to confirm that they are now different.

# %%
# Creating new variable
my_list_copy = list(my_list)

# Changing something in my list copy to prove they are not the same list.
my_list_copy[3] = "blue"

print(my_list, "is not the same as", my_list_copy)
# Out:
# ['Sanjo', 28, 2.3, 'red'] is not the same as ['Sanjo', 28, 2.3, 'blue']

# %% [markdown]
# # Exercise 7
# ## Final Output
#
# Print out all final variables and lists to see the changes.

# %%
#Printing variables
print("my_name equals ", my_name)
print("my_age equals ", my_age)
print("my_height equals ", my_height)
print("is_student equals ", is_student)

#Printing the lists
print("my_list_2 equals ", my_list_2)
print("my_list_copy equals ", my_list_copy)
print("my_List equals ", my_list)
# Out:
# my_name equals  Sanjo
# my_age equals  28
# my_height equals  1.9
# is_student equals  True
# my_list_2 equals  [28, 1.9]
# my_list_copy equals  ['Sanjo', 28, 2.3, 'blue']
# my_List equals  ['Sanjo', 28, 2.3, 'red']
